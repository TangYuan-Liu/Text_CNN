# %%
import pandas as pd
import numpy as np
import jieba
from sklearn.cross_validation import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from keras.preprocessing.text import Tokenizer
from sklearn.metrics import classification_report
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import StratifiedKFold
from xgboost import XGBClassifier
import warnings
warnings.filterwarnings("ignore")
# Out:
# C:\Users\Administrator\Documents\Anaconda3\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# C:\Users\Administrator\Documents\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# 6分类

# %%
df = pd.read_csv('data/27378.csv',index_col=0)
print('分数分布:')
print(df['复核结果'].value_counts())

with open('ChineseStopWords/ChineseStopWords.txt', encoding='utf-8') as f:
    stop_words = set([l.strip() for l in f])
    
def segmentWord(cont):
    c = []
    b = []
    for i in cont:
        n = 0
        text = ""
        word_list = list(jieba.cut(i, cut_all=False))
        for word in word_list:
            if word not in stop_words and word != '\r\n':
                text += word
                text += ' '
            else:
                n += 1
        c.append(text)
        b.append(n)
    return c,b

df['回答内容'],df['去停频数'] = segmentWord(df['回答内容'])
df['回答长度'] = df['回答内容'].map(lambda x: len(x))
con_data = df['回答内容'].values

token = Tokenizer(num_words=3300)
token.fit_on_texts(con_data)
data_x_mat = token.texts_to_matrix(con_data)
x_data2 = df[['回答长度','去停频数']].values
x_data = np.hstack([data_x_mat,x_data2])
y_data = df['复核结果'].values

x_train, x_test, y_train, y_test = train_test_split(x_data,y_data,test_size=0.1, random_state=2020)
print('训练集分布:')
for i in range(6):
    print('{}:{}'.format(i,len(y_train[y_train==i])))

print('测试集分布:')
for i in range(6):
    print('{}:{}'.format(i,len(y_test[y_test==i])))
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\ADMINI~1\AppData\Local\Temp\jieba.cache
# 分数分布:
# 3    740
# 4    503
# 2    191
# 1    167
# 5     67
# 0     14
# Name: 复核结果, dtype: int64
# Loading model cost 1.053 seconds.
# Prefix dict has been built succesfully.
# 训练集分布:
# 0:12
# 1:146
# 2:171
# 3:670
# 4:453
# 5:61
# 测试集分布:
# 0:2
# 1:21
# 2:20
# 3:70
# 4:50
# 5:6

# %%
# cv_params = {'max_depth': [3, 4, 5, 6, 7, 8, 9, 10], 'min_child_weight': [1, 2, 3, 4, 5, 6]}
# other_params = {'learning_rate': 0.1, 'n_estimators': 100, 'max_depth': 5, 'min_child_weight': 1, 'seed': 0,
#                 'subsample': 0.8, 'colsample_bytree': 0.8, 'gamma': 0, 'reg_alpha': 0, 'reg_lambda': 1}
# model = XGBClassifier(**other_params)
# optimized_GBM = GridSearchCV(estimator=model, param_grid=cv_params, scoring='accuracy', cv=2, verbose=3)
# optimized_GBM.fit(x_train, y_train)
# evalute_result = optimized_GBM.grid_scores_
# print('每轮迭代运行结果:{0}'.format(evalute_result))
# print('参数的最佳取值：{0}'.format(optimized_GBM.best_params_))
# print('最佳模型得分:{0}'.format(optimized_GBM.best_score_))

# %%
model = XGBClassifier(
    learning_rate =0.1,
    n_estimators=300,
    max_depth=3,
    min_child_weight=1,
    gamma=0.3,
    subsample=0.8,
    colsample_bytree=0.8,
    reg_alpha=0,
    reg_lambda=1,
    objective= 'multi:softmax',
    nthread=-1,
    scale_pos_weight=1,
    seed=27
)
eval_list = [(x_train,y_train),(x_test,y_test)]
model.fit(x_train,y_train,verbose=True,eval_set=eval_list,eval_metric='mlogloss', early_stopping_rounds=10)
y_pred = model.predict(x_test)
print(accuracy_score(y_test, y_pred))


labels = list(set(y_test))
print('标签顺序:')
print(labels)
print('测试集混淆矩阵:')
print(confusion_matrix(y_test, y_pred, labels = labels))

y_pred_train = model.predict(x_train)
labels = list(set(y_train))
print('训练集混淆矩阵:')
print(confusion_matrix(y_train, y_pred_train, labels = labels))

target_names = ['class 0','class 1', 'class 2', 'class 3' , 'class 4','class 5']
print(classification_report(y_test, y_pred, target_names=target_names))

print ("修正MSE:")
c = [abs(y_test[i] - y_pred[i]) for i in range(len(y_test))]
mse = 1 - sum(c)/(2*len(y_test))
print (mse)
# Out:
# [0]	validation_0-mlogloss:1.66501	validation_1-mlogloss:1.66851
# Multiple eval metrics have been passed: 'validation_1-mlogloss' will be used for early stopping.
#
# Will train until validation_1-mlogloss hasn't improved in 10 rounds.
# [1]	validation_0-mlogloss:1.55941	validation_1-mlogloss:1.57107
# [2]	validation_0-mlogloss:1.47596	validation_1-mlogloss:1.4898
# [3]	validation_0-mlogloss:1.40038	validation_1-mlogloss:1.41335
# [4]	validation_0-mlogloss:1.33292	validation_1-mlogloss:1.34652
# [5]	validation_0-mlogloss:1.27139	validation_1-mlogloss:1.28339
# [6]	validation_0-mlogloss:1.22096	validation_1-mlogloss:1.23587
# [7]	validation_0-mlogloss:1.17342	validation_1-mlogloss:1.18894
# [8]	validation_0-mlogloss:1.13126	validation_1-mlogloss:1.1487
# [9]	validation_0-mlogloss:1.09161	validation_1-mlogloss:1.11423
# [10]	validation_0-mlogloss:1.05839	validation_1-mlogloss:1.08532
# [11]	validation_0-mlogloss:1.02721	validation_1-mlogloss:1.05481
# [12]	validation_0-mlogloss:0.998091	validation_1-mlogloss:1.02769
# [13]	validation_0-mlogloss:0.972652	validation_1-mlogloss:1.00501
# [14]	validation_0-mlogloss:0.947763	validation_1-mlogloss:0.982736
# [15]	validation_0-mlogloss:0.924867	validation_1-mlogloss:0.96314
# [16]	validation_0-mlogloss:0.903502	validation_1-mlogloss:0.943534
# [17]	validation_0-mlogloss:0.884562	validation_1-mlogloss:0.926185
# [18]	validation_0-mlogloss:0.866461	validation_1-mlogloss:0.908769
# [19]	validation_0-mlogloss:0.849704	validation_1-mlogloss:0.893469
# [20]	validation_0-mlogloss:0.833358	validation_1-mlogloss:0.877356
# [21]	validation_0-mlogloss:0.818357	validation_1-mlogloss:0.865164
# [22]	validation_0-mlogloss:0.804853	validation_1-mlogloss:0.85438
# [23]	validation_0-mlogloss:0.790708	validation_1-mlogloss:0.843738
# [24]	validation_0-mlogloss:0.777761	validation_1-mlogloss:0.833758
# [25]	validation_0-mlogloss:0.765901	validation_1-mlogloss:0.824391
# [26]	validation_0-mlogloss:0.753997	validation_1-mlogloss:0.814534
# [27]	validation_0-mlogloss:0.742686	validation_1-mlogloss:0.805051
# [28]	validation_0-mlogloss:0.732427	validation_1-mlogloss:0.797749
# [29]	validation_0-mlogloss:0.722491	validation_1-mlogloss:0.789337
# [30]	validation_0-mlogloss:0.713124	validation_1-mlogloss:0.783364
# [31]	validation_0-mlogloss:0.703744	validation_1-mlogloss:0.776369
# [32]	validation_0-mlogloss:0.695635	validation_1-mlogloss:0.770791
# [33]	validation_0-mlogloss:0.687794	validation_1-mlogloss:0.76311
# [34]	validation_0-mlogloss:0.680678	validation_1-mlogloss:0.758597
# [35]	validation_0-mlogloss:0.673406	validation_1-mlogloss:0.754027
# [36]	validation_0-mlogloss:0.666409	validation_1-mlogloss:0.748571
# [37]	validation_0-mlogloss:0.659278	validation_1-mlogloss:0.745495
# [38]	validation_0-mlogloss:0.652977	validation_1-mlogloss:0.741816
# [39]	validation_0-mlogloss:0.64704	validation_1-mlogloss:0.737797
# [40]	validation_0-mlogloss:0.641361	validation_1-mlogloss:0.734374
# [41]	validation_0-mlogloss:0.636013	validation_1-mlogloss:0.729209
# [42]	validation_0-mlogloss:0.631285	validation_1-mlogloss:0.725832
# [43]	validation_0-mlogloss:0.626198	validation_1-mlogloss:0.723013
# [44]	validation_0-mlogloss:0.621188	validation_1-mlogloss:0.718433
# [45]	validation_0-mlogloss:0.616874	validation_1-mlogloss:0.714225
# [46]	validation_0-mlogloss:0.61278	validation_1-mlogloss:0.710758
# [47]	validation_0-mlogloss:0.607553	validation_1-mlogloss:0.710529
# [48]	validation_0-mlogloss:0.602109	validation_1-mlogloss:0.707607
# [49]	validation_0-mlogloss:0.596515	validation_1-mlogloss:0.706014
# [50]	validation_0-mlogloss:0.592385	validation_1-mlogloss:0.703597
# [51]	validation_0-mlogloss:0.588818	validation_1-mlogloss:0.702604
# [52]	validation_0-mlogloss:0.58469	validation_1-mlogloss:0.699683
# [53]	validation_0-mlogloss:0.57976	validation_1-mlogloss:0.698049
# [54]	validation_0-mlogloss:0.576071	validation_1-mlogloss:0.696972
# [55]	validation_0-mlogloss:0.57322	validation_1-mlogloss:0.69612
# [56]	validation_0-mlogloss:0.570193	validation_1-mlogloss:0.694141
# [57]	validation_0-mlogloss:0.566641	validation_1-mlogloss:0.693253
# [58]	validation_0-mlogloss:0.56376	validation_1-mlogloss:0.69157
# [59]	validation_0-mlogloss:0.560398	validation_1-mlogloss:0.6905
# [60]	validation_0-mlogloss:0.557111	validation_1-mlogloss:0.689301
# [61]	validation_0-mlogloss:0.554135	validation_1-mlogloss:0.689146
# [62]	validation_0-mlogloss:0.55049	validation_1-mlogloss:0.687778
# [63]	validation_0-mlogloss:0.547233	validation_1-mlogloss:0.686387
# [64]	validation_0-mlogloss:0.544364	validation_1-mlogloss:0.685997
# [65]	validation_0-mlogloss:0.541232	validation_1-mlogloss:0.685097
# [66]	validation_0-mlogloss:0.538694	validation_1-mlogloss:0.684523
# [67]	validation_0-mlogloss:0.536383	validation_1-mlogloss:0.683181
# [68]	validation_0-mlogloss:0.533825	validation_1-mlogloss:0.681862
# [69]	validation_0-mlogloss:0.531029	validation_1-mlogloss:0.681259
# [70]	validation_0-mlogloss:0.528687	validation_1-mlogloss:0.680876
# [71]	validation_0-mlogloss:0.526115	validation_1-mlogloss:0.680246
# [72]	validation_0-mlogloss:0.523967	validation_1-mlogloss:0.67909
# [73]	validation_0-mlogloss:0.521578	validation_1-mlogloss:0.676851
# [74]	validation_0-mlogloss:0.518347	validation_1-mlogloss:0.674937
# [75]	validation_0-mlogloss:0.515805	validation_1-mlogloss:0.674896
# [76]	validation_0-mlogloss:0.513924	validation_1-mlogloss:0.674296
# [77]	validation_0-mlogloss:0.511741	validation_1-mlogloss:0.673592
# [78]	validation_0-mlogloss:0.510067	validation_1-mlogloss:0.67306
# [79]	validation_0-mlogloss:0.506769	validation_1-mlogloss:0.670674
# [80]	validation_0-mlogloss:0.504437	validation_1-mlogloss:0.670395
# [81]	validation_0-mlogloss:0.502056	validation_1-mlogloss:0.668577
# [82]	validation_0-mlogloss:0.500086	validation_1-mlogloss:0.667675
# [83]	validation_0-mlogloss:0.497843	validation_1-mlogloss:0.668013
# [84]	validation_0-mlogloss:0.495863	validation_1-mlogloss:0.667431
# [85]	validation_0-mlogloss:0.49342	validation_1-mlogloss:0.666843
# [86]	validation_0-mlogloss:0.491271	validation_1-mlogloss:0.666268
# [87]	validation_0-mlogloss:0.489055	validation_1-mlogloss:0.667885
# [88]	validation_0-mlogloss:0.487035	validation_1-mlogloss:0.668693
# [89]	validation_0-mlogloss:0.485022	validation_1-mlogloss:0.668741
# [90]	validation_0-mlogloss:0.483438	validation_1-mlogloss:0.667676
# [91]	validation_0-mlogloss:0.481222	validation_1-mlogloss:0.667484
# [92]	validation_0-mlogloss:0.479573	validation_1-mlogloss:0.666712
# [93]	validation_0-mlogloss:0.477854	validation_1-mlogloss:0.666454
# [94]	validation_0-mlogloss:0.47602	validation_1-mlogloss:0.666943
# [95]	validation_0-mlogloss:0.474257	validation_1-mlogloss:0.667001
# [96]	validation_0-mlogloss:0.472076	validation_1-mlogloss:0.665612
# [97]	validation_0-mlogloss:0.469777	validation_1-mlogloss:0.665404
# [98]	validation_0-mlogloss:0.46799	validation_1-mlogloss:0.665202
# [99]	validation_0-mlogloss:0.466208	validation_1-mlogloss:0.665641
# [100]	validation_0-mlogloss:0.464665	validation_1-mlogloss:0.664667
# [101]	validation_0-mlogloss:0.462687	validation_1-mlogloss:0.665014
# [102]	validation_0-mlogloss:0.460959	validation_1-mlogloss:0.664433
# [103]	validation_0-mlogloss:0.459357	validation_1-mlogloss:0.664073
# [104]	validation_0-mlogloss:0.457917	validation_1-mlogloss:0.663882
# [105]	validation_0-mlogloss:0.456561	validation_1-mlogloss:0.663865
# [106]	validation_0-mlogloss:0.454761	validation_1-mlogloss:0.662819
# [107]	validation_0-mlogloss:0.453309	validation_1-mlogloss:0.663344
# [108]	validation_0-mlogloss:0.451895	validation_1-mlogloss:0.662801
# [109]	validation_0-mlogloss:0.450083	validation_1-mlogloss:0.661152
# [110]	validation_0-mlogloss:0.448761	validation_1-mlogloss:0.660243
# [111]	validation_0-mlogloss:0.447347	validation_1-mlogloss:0.660205
# [112]	validation_0-mlogloss:0.445727	validation_1-mlogloss:0.658929
# [113]	validation_0-mlogloss:0.443943	validation_1-mlogloss:0.658456
# [114]	validation_0-mlogloss:0.442799	validation_1-mlogloss:0.658071
# [115]	validation_0-mlogloss:0.44168	validation_1-mlogloss:0.657138
# [116]	validation_0-mlogloss:0.440078	validation_1-mlogloss:0.658775
# [117]	validation_0-mlogloss:0.438772	validation_1-mlogloss:0.659217
# [118]	validation_0-mlogloss:0.437104	validation_1-mlogloss:0.659598
# [119]	validation_0-mlogloss:0.435579	validation_1-mlogloss:0.659127
# [120]	validation_0-mlogloss:0.434232	validation_1-mlogloss:0.659669
# [121]	validation_0-mlogloss:0.432848	validation_1-mlogloss:0.660638
# [122]	validation_0-mlogloss:0.431844	validation_1-mlogloss:0.660609
# [123]	validation_0-mlogloss:0.430535	validation_1-mlogloss:0.661821
# [124]	validation_0-mlogloss:0.429141	validation_1-mlogloss:0.663158
# [125]	validation_0-mlogloss:0.427967	validation_1-mlogloss:0.663263
# Stopping. Best iteration:
# [115]	validation_0-mlogloss:0.44168	validation_1-mlogloss:0.657138
#
# 0.7159763313609467
# 标签顺序:
# [0, 1, 2, 3, 4, 5]
# 测试集混淆矩阵:
# [[ 1  1  0  0  0  0]
#  [ 1 16  2  2  0  0]
#  [ 0  4  5 10  0  1]
#  [ 0  0  1 59 10  0]
#  [ 0  0  0 12 38  0]
#  [ 0  0  0  0  4  2]]
# 训练集混淆矩阵:
# [[  5   7   0   0   0   0]
#  [  0 132   9   5   0   0]
#  [  0  12 107  50   2   0]
#  [  0   0   8 618  44   0]
#  [  0   0   0  78 375   0]
#  [  0   0   0   0   5  56]]
#              precision    recall  f1-score   support
#
#     class 0       0.50      0.50      0.50         2
#     class 1       0.76      0.76      0.76        21
#     class 2       0.62      0.25      0.36        20
#     class 3       0.71      0.84      0.77        70
#     class 4       0.73      0.76      0.75        50
#     class 5       0.67      0.33      0.44         6
#
# avg / total       0.71      0.72      0.70       169
#
# 修正MSE:
# 0.8461538461538461

# %% [markdown]
# 5分类

# %%
df = pd.read_csv('data/27378.csv',index_col=0)

# 0,1合并
df['复核结果'].replace(0,1,inplace=True)
# df['复核结果'].replace(4,3,inplace=True)
# df['复核结果'].replace(5,4,inplace=True)
print(df['复核结果'].value_counts())

with open('ChineseStopWords/ChineseStopWords.txt', encoding='utf-8') as f:
    stop_words = set([l.strip() for l in f])
    
def segmentWord(cont):
    c = []
    b = []
    for i in cont:
        n = 0
        text = ""
        word_list = list(jieba.cut(i, cut_all=False))
        for word in word_list:
            if word not in stop_words and word != '\r\n':
                text += word
                text += ' '
            else:
                n += 1
        c.append(text)
        b.append(n)
    return c,b

df['回答内容'],df['去停频数'] = segmentWord(df['回答内容'])
df['回答长度'] = df['回答内容'].map(lambda x: len(x))
con_data = df['回答内容'].values

token = Tokenizer(num_words=3300)
token.fit_on_texts(con_data)
data_x_mat = token.texts_to_matrix(con_data)
x_data2 = df[['回答长度','去停频数']].values
x_data = np.hstack([data_x_mat,x_data2])
y_data = df['复核结果'].values

x_train, x_test, y_train, y_test = train_test_split(x_data,y_data,test_size=0.1, random_state=2017)
print('训练集分布:')
for i in range(1,6):
    print('{}:{}'.format(i,len(y_train[y_train==i])))

print('测试集分布:')
for i in range(1,6):
    print('{}:{}'.format(i,len(y_test[y_test==i])))
# Out:
# 3    740
# 4    503
# 2    191
# 1    181
# 5     67
# Name: 复核结果, dtype: int64
# 训练集分布:
# 1:164
# 2:174
# 3:660
# 4:454
# 5:61
# 测试集分布:
# 1:17
# 2:17
# 3:80
# 4:49
# 5:6

# %%
model = XGBClassifier(
    learning_rate =0.1,
    n_estimators=500,
    max_depth=3,
    min_child_weight=1,
    gamma=0.3,
    subsample=0.8,
    colsample_bytree=0.8,
    reg_alpha=0,
    reg_lambda=1,
    objective= 'multi:softmax',
    nthread=-1,
    scale_pos_weight=10,
    seed=27
)
eval_list = [(x_train,y_train),(x_test,y_test)]
model.fit(x_train,y_train,verbose=True,eval_set=eval_list,eval_metric='mlogloss', early_stopping_rounds=10)
y_pred = model.predict(x_test)
print(accuracy_score(y_test, y_pred))


labels = list(set(y_test))
print('标签顺序:')
print(labels)
print('测试集混淆矩阵:')
print(confusion_matrix(y_test, y_pred, labels = labels))

y_pred_train = model.predict(x_train)
labels = list(set(y_train))
print('训练集混淆矩阵:')
print(confusion_matrix(y_train, y_pred_train, labels = labels))

target_names = ['class 1', 'class 2', 'class 3' , 'class 4','class 5']
print(classification_report(y_test, y_pred, target_names=target_names))

print ("修正MSE:")
c = [abs(y_test[i] - y_pred[i]) for i in range(len(y_test))]
mse = 1 - sum(c)/(2*len(y_test))
print (mse)
# Out:
# [0]	validation_0-mlogloss:1.5065	validation_1-mlogloss:1.51247
# Multiple eval metrics have been passed: 'validation_1-mlogloss' will be used for early stopping.
#
# Will train until validation_1-mlogloss hasn't improved in 10 rounds.
# [1]	validation_0-mlogloss:1.41939	validation_1-mlogloss:1.43046
# [2]	validation_0-mlogloss:1.3529	validation_1-mlogloss:1.36843
# [3]	validation_0-mlogloss:1.28806	validation_1-mlogloss:1.30417
# [4]	validation_0-mlogloss:1.2322	validation_1-mlogloss:1.24904
# [5]	validation_0-mlogloss:1.17688	validation_1-mlogloss:1.20043
# [6]	validation_0-mlogloss:1.131	validation_1-mlogloss:1.15867
# [7]	validation_0-mlogloss:1.09132	validation_1-mlogloss:1.12176
# [8]	validation_0-mlogloss:1.05286	validation_1-mlogloss:1.08729
# [9]	validation_0-mlogloss:1.01924	validation_1-mlogloss:1.05605
# [10]	validation_0-mlogloss:0.989032	validation_1-mlogloss:1.02766
# [11]	validation_0-mlogloss:0.96002	validation_1-mlogloss:1.00122
# [12]	validation_0-mlogloss:0.936533	validation_1-mlogloss:0.980837
# [13]	validation_0-mlogloss:0.911989	validation_1-mlogloss:0.961467
# [14]	validation_0-mlogloss:0.890824	validation_1-mlogloss:0.945236
# [15]	validation_0-mlogloss:0.869856	validation_1-mlogloss:0.929779
# [16]	validation_0-mlogloss:0.851091	validation_1-mlogloss:0.912782
# [17]	validation_0-mlogloss:0.833124	validation_1-mlogloss:0.897034
# [18]	validation_0-mlogloss:0.816464	validation_1-mlogloss:0.883493
# [19]	validation_0-mlogloss:0.801752	validation_1-mlogloss:0.869927
# [20]	validation_0-mlogloss:0.788536	validation_1-mlogloss:0.857205
# [21]	validation_0-mlogloss:0.775308	validation_1-mlogloss:0.844746
# [22]	validation_0-mlogloss:0.762295	validation_1-mlogloss:0.832759
# [23]	validation_0-mlogloss:0.750801	validation_1-mlogloss:0.822518
# [24]	validation_0-mlogloss:0.739782	validation_1-mlogloss:0.813389
# [25]	validation_0-mlogloss:0.728885	validation_1-mlogloss:0.806809
# [26]	validation_0-mlogloss:0.718244	validation_1-mlogloss:0.798546
# [27]	validation_0-mlogloss:0.709587	validation_1-mlogloss:0.792476
# [28]	validation_0-mlogloss:0.700228	validation_1-mlogloss:0.786857
# [29]	validation_0-mlogloss:0.69173	validation_1-mlogloss:0.777637
# [30]	validation_0-mlogloss:0.68313	validation_1-mlogloss:0.768809
# [31]	validation_0-mlogloss:0.674572	validation_1-mlogloss:0.7605
# [32]	validation_0-mlogloss:0.666658	validation_1-mlogloss:0.754161
# [33]	validation_0-mlogloss:0.659778	validation_1-mlogloss:0.747235
# [34]	validation_0-mlogloss:0.653293	validation_1-mlogloss:0.74329
# [35]	validation_0-mlogloss:0.646282	validation_1-mlogloss:0.74159
# [36]	validation_0-mlogloss:0.639467	validation_1-mlogloss:0.737422
# [37]	validation_0-mlogloss:0.63268	validation_1-mlogloss:0.733401
# [38]	validation_0-mlogloss:0.627241	validation_1-mlogloss:0.729864
# [39]	validation_0-mlogloss:0.621388	validation_1-mlogloss:0.727241
# [40]	validation_0-mlogloss:0.616369	validation_1-mlogloss:0.723261
# [41]	validation_0-mlogloss:0.611424	validation_1-mlogloss:0.719532
# [42]	validation_0-mlogloss:0.606199	validation_1-mlogloss:0.716658
# [43]	validation_0-mlogloss:0.60086	validation_1-mlogloss:0.714189
# [44]	validation_0-mlogloss:0.596002	validation_1-mlogloss:0.71132
# [45]	validation_0-mlogloss:0.592022	validation_1-mlogloss:0.70855
# [46]	validation_0-mlogloss:0.587422	validation_1-mlogloss:0.706459
# [47]	validation_0-mlogloss:0.583129	validation_1-mlogloss:0.704159
# [48]	validation_0-mlogloss:0.578271	validation_1-mlogloss:0.702446
# [49]	validation_0-mlogloss:0.573526	validation_1-mlogloss:0.700263
# [50]	validation_0-mlogloss:0.569004	validation_1-mlogloss:0.699911
# [51]	validation_0-mlogloss:0.565561	validation_1-mlogloss:0.698447
# [52]	validation_0-mlogloss:0.561581	validation_1-mlogloss:0.696313
# [53]	validation_0-mlogloss:0.558454	validation_1-mlogloss:0.694528
# [54]	validation_0-mlogloss:0.554842	validation_1-mlogloss:0.692284
# [55]	validation_0-mlogloss:0.551581	validation_1-mlogloss:0.690687
# [56]	validation_0-mlogloss:0.548197	validation_1-mlogloss:0.688903
# [57]	validation_0-mlogloss:0.545138	validation_1-mlogloss:0.686953
# [58]	validation_0-mlogloss:0.541755	validation_1-mlogloss:0.684456
# [59]	validation_0-mlogloss:0.538833	validation_1-mlogloss:0.68289
# [60]	validation_0-mlogloss:0.535886	validation_1-mlogloss:0.681894
# [61]	validation_0-mlogloss:0.532932	validation_1-mlogloss:0.680896
# [62]	validation_0-mlogloss:0.529745	validation_1-mlogloss:0.679648
# [63]	validation_0-mlogloss:0.526859	validation_1-mlogloss:0.677526
# [64]	validation_0-mlogloss:0.52385	validation_1-mlogloss:0.676332
# [65]	validation_0-mlogloss:0.520879	validation_1-mlogloss:0.675619
# [66]	validation_0-mlogloss:0.518084	validation_1-mlogloss:0.674791
# [67]	validation_0-mlogloss:0.515009	validation_1-mlogloss:0.673859
# [68]	validation_0-mlogloss:0.511846	validation_1-mlogloss:0.674184
# [69]	validation_0-mlogloss:0.509579	validation_1-mlogloss:0.672379
# [70]	validation_0-mlogloss:0.506985	validation_1-mlogloss:0.672025
# [71]	validation_0-mlogloss:0.50461	validation_1-mlogloss:0.67129
# [72]	validation_0-mlogloss:0.501926	validation_1-mlogloss:0.671161
# [73]	validation_0-mlogloss:0.499488	validation_1-mlogloss:0.670225
# [74]	validation_0-mlogloss:0.496893	validation_1-mlogloss:0.668625
# [75]	validation_0-mlogloss:0.4943	validation_1-mlogloss:0.667038
# [76]	validation_0-mlogloss:0.492194	validation_1-mlogloss:0.665949
# [77]	validation_0-mlogloss:0.490276	validation_1-mlogloss:0.665052
# [78]	validation_0-mlogloss:0.488324	validation_1-mlogloss:0.664367
# [79]	validation_0-mlogloss:0.485717	validation_1-mlogloss:0.665022
# [80]	validation_0-mlogloss:0.483738	validation_1-mlogloss:0.664279
# [81]	validation_0-mlogloss:0.481459	validation_1-mlogloss:0.662606
# [82]	validation_0-mlogloss:0.47903	validation_1-mlogloss:0.662125
# [83]	validation_0-mlogloss:0.476299	validation_1-mlogloss:0.660545
# [84]	validation_0-mlogloss:0.474514	validation_1-mlogloss:0.661124
# [85]	validation_0-mlogloss:0.472067	validation_1-mlogloss:0.661072
# [86]	validation_0-mlogloss:0.470016	validation_1-mlogloss:0.660407
# [87]	validation_0-mlogloss:0.468119	validation_1-mlogloss:0.66021
# [88]	validation_0-mlogloss:0.466289	validation_1-mlogloss:0.661807
# [89]	validation_0-mlogloss:0.464468	validation_1-mlogloss:0.660917
# [90]	validation_0-mlogloss:0.462957	validation_1-mlogloss:0.660643
# [91]	validation_0-mlogloss:0.461014	validation_1-mlogloss:0.659839
# [92]	validation_0-mlogloss:0.459142	validation_1-mlogloss:0.659963
# [93]	validation_0-mlogloss:0.457413	validation_1-mlogloss:0.659716
# [94]	validation_0-mlogloss:0.455651	validation_1-mlogloss:0.65885
# [95]	validation_0-mlogloss:0.453841	validation_1-mlogloss:0.657849
# [96]	validation_0-mlogloss:0.451996	validation_1-mlogloss:0.657362
# [97]	validation_0-mlogloss:0.450588	validation_1-mlogloss:0.65684
# [98]	validation_0-mlogloss:0.449248	validation_1-mlogloss:0.656317
# [99]	validation_0-mlogloss:0.447493	validation_1-mlogloss:0.654289
# [100]	validation_0-mlogloss:0.445915	validation_1-mlogloss:0.653503
# [101]	validation_0-mlogloss:0.444518	validation_1-mlogloss:0.653387
# [102]	validation_0-mlogloss:0.442702	validation_1-mlogloss:0.653447
# [103]	validation_0-mlogloss:0.44106	validation_1-mlogloss:0.653596
# [104]	validation_0-mlogloss:0.439745	validation_1-mlogloss:0.652863
# [105]	validation_0-mlogloss:0.438281	validation_1-mlogloss:0.650677
# [106]	validation_0-mlogloss:0.436727	validation_1-mlogloss:0.649549
# [107]	validation_0-mlogloss:0.435374	validation_1-mlogloss:0.65057
# [108]	validation_0-mlogloss:0.433707	validation_1-mlogloss:0.649467
# [109]	validation_0-mlogloss:0.43265	validation_1-mlogloss:0.649329
# [110]	validation_0-mlogloss:0.430529	validation_1-mlogloss:0.648843
# [111]	validation_0-mlogloss:0.428795	validation_1-mlogloss:0.648281
# [112]	validation_0-mlogloss:0.42715	validation_1-mlogloss:0.647694
# [113]	validation_0-mlogloss:0.425887	validation_1-mlogloss:0.647596
# [114]	validation_0-mlogloss:0.424496	validation_1-mlogloss:0.64658
# [115]	validation_0-mlogloss:0.422752	validation_1-mlogloss:0.646175
# [116]	validation_0-mlogloss:0.421401	validation_1-mlogloss:0.646485
# [117]	validation_0-mlogloss:0.419589	validation_1-mlogloss:0.645571
# [118]	validation_0-mlogloss:0.417899	validation_1-mlogloss:0.644937
# [119]	validation_0-mlogloss:0.416443	validation_1-mlogloss:0.644216
# [120]	validation_0-mlogloss:0.41477	validation_1-mlogloss:0.644223
# [121]	validation_0-mlogloss:0.413314	validation_1-mlogloss:0.644444
# [122]	validation_0-mlogloss:0.412131	validation_1-mlogloss:0.64327
# [123]	validation_0-mlogloss:0.411011	validation_1-mlogloss:0.642937
# [124]	validation_0-mlogloss:0.409697	validation_1-mlogloss:0.641893
# [125]	validation_0-mlogloss:0.408118	validation_1-mlogloss:0.640898
# [126]	validation_0-mlogloss:0.406869	validation_1-mlogloss:0.641609
# [127]	validation_0-mlogloss:0.405571	validation_1-mlogloss:0.641036
# [128]	validation_0-mlogloss:0.40418	validation_1-mlogloss:0.641124
# [129]	validation_0-mlogloss:0.402841	validation_1-mlogloss:0.639874
# [130]	validation_0-mlogloss:0.401443	validation_1-mlogloss:0.641482
# [131]	validation_0-mlogloss:0.399823	validation_1-mlogloss:0.640178
# [132]	validation_0-mlogloss:0.398639	validation_1-mlogloss:0.639757
# [133]	validation_0-mlogloss:0.397216	validation_1-mlogloss:0.638632
# [134]	validation_0-mlogloss:0.395949	validation_1-mlogloss:0.638589
# [135]	validation_0-mlogloss:0.394736	validation_1-mlogloss:0.636962
# [136]	validation_0-mlogloss:0.393378	validation_1-mlogloss:0.636031
# [137]	validation_0-mlogloss:0.392159	validation_1-mlogloss:0.636727
# [138]	validation_0-mlogloss:0.390899	validation_1-mlogloss:0.636506
# [139]	validation_0-mlogloss:0.38956	validation_1-mlogloss:0.637152
# [140]	validation_0-mlogloss:0.388469	validation_1-mlogloss:0.63733
# [141]	validation_0-mlogloss:0.387284	validation_1-mlogloss:0.63924
# [142]	validation_0-mlogloss:0.385902	validation_1-mlogloss:0.639073
# [143]	validation_0-mlogloss:0.384954	validation_1-mlogloss:0.638961
# [144]	validation_0-mlogloss:0.38385	validation_1-mlogloss:0.638364
# [145]	validation_0-mlogloss:0.382514	validation_1-mlogloss:0.638019
# [146]	validation_0-mlogloss:0.381072	validation_1-mlogloss:0.638622
# Stopping. Best iteration:
# [136]	validation_0-mlogloss:0.393378	validation_1-mlogloss:0.636031
#
# 0.727810650887574
# 标签顺序:
# [1, 2, 3, 4, 5]
# 测试集混淆矩阵:
# [[13  4  0  0  0]
#  [ 4  9  3  1  0]
#  [ 0  2 63 15  0]
#  [ 0  0 13 36  0]
#  [ 0  0  0  4  2]]
# 训练集混淆矩阵:
# [[151  10   3   0   0]
#  [ 14 122  37   1   0]
#  [  0  12 610  38   0]
#  [  0   2  70 382   0]
#  [  0   0   0   2  59]]
#              precision    recall  f1-score   support
#
#     class 1       0.76      0.76      0.76        17
#     class 2       0.60      0.53      0.56        17
#     class 3       0.80      0.79      0.79        80
#     class 4       0.64      0.73      0.69        49
#     class 5       1.00      0.33      0.50         6
#
# avg / total       0.74      0.73      0.73       169
#
# 修正MSE:
# 0.8609467455621302

# %%
model.save_model('q3_xgb0.7278(5分类).model')

# %% [markdown]
# 4分类

# %%
df = pd.read_csv('data/27378.csv',index_col=0)

# 0,1,2合并
df['复核结果'].replace(0,1,inplace=True)
df['复核结果'].replace(2,1,inplace=True)
df['复核结果'].replace(3,2,inplace=True)
df['复核结果'].replace(4,3,inplace=True)
df['复核结果'].replace(5,4,inplace=True)

with open('ChineseStopWords/ChineseStopWords.txt', encoding='utf-8') as f:
    stop_words = set([l.strip() for l in f])
    
def segmentWord(cont):
    c = []
    b = []
    for i in cont:
        n = 0
        text = ""
        word_list = list(jieba.cut(i, cut_all=False))
        for word in word_list:
            if word not in stop_words and word != '\r\n':
                text += word
                text += ' '
            else:
                n += 1
        c.append(text)
        b.append(n)
    return c,b

df['回答内容'],df['去停频数'] = segmentWord(df['回答内容'])
df['回答长度'] = df['回答内容'].map(lambda x: len(x))
con_data = df['回答内容'].values

token = Tokenizer(num_words=3300)
token.fit_on_texts(con_data)
data_x_mat = token.texts_to_matrix(con_data)
x_data2 = df[['回答长度','去停频数']].values
x_data = np.hstack([data_x_mat,x_data2])
y_data = df['复核结果'].values

x_train, x_test, y_train, y_test = train_test_split(x_data,y_data,test_size=0.1, random_state=2019)
print('训练集分布:')
for i in range(1,5):
    print('{}:{}'.format(i,len(y_train[y_train==i])))

print('测试集分布:')
for i in range(1,5):
    print('{}:{}'.format(i,len(y_test[y_test==i])))
# Out:
# 训练集分布:
# 1:342
# 2:667
# 3:448
# 4:56
# 测试集分布:
# 1:30
# 2:73
# 3:55
# 4:11

# %%
model = XGBClassifier(
    learning_rate =0.1,
    n_estimators=100,
    max_depth=3,
    min_child_weight=1,
    gamma=0.3,
    subsample=0.8,
    colsample_bytree=0.8,
    reg_alpha=0,
    reg_lambda=1,
    objective= 'multi:softmax',
    nthread=-1,
    scale_pos_weight=1,
    seed=27
)
eval_list = [(x_train,y_train),(x_test,y_test)]
model.fit(x_train,y_train,verbose=True,eval_set=eval_list,eval_metric='mlogloss', early_stopping_rounds=10)
y_pred = model.predict(x_test)
print(accuracy_score(y_test, y_pred))


labels = list(set(y_test))
print('标签顺序:')
print(labels)
print('测试集混淆矩阵:')
print(confusion_matrix(y_test, y_pred, labels = labels))

y_pred_train = model.predict(x_train)
labels = list(set(y_train))
print('训练集混淆矩阵:')
print(confusion_matrix(y_train, y_pred_train, labels = labels))

target_names = ['class 1', 'class 2', 'class 3' , 'class 4']
print(classification_report(y_test, y_pred, target_names=target_names))

print ("修正MSE:")
c = [abs(y_test[i] - y_pred[i]) for i in range(len(y_test))]
mse = 1 - sum(c)/(2*len(y_test))
print (mse)
# Out:
# [0]	validation_0-mlogloss:1.29985	validation_1-mlogloss:1.30676
# Multiple eval metrics have been passed: 'validation_1-mlogloss' will be used for early stopping.
#
# Will train until validation_1-mlogloss hasn't improved in 10 rounds.
# [1]	validation_0-mlogloss:1.22911	validation_1-mlogloss:1.23678
# [2]	validation_0-mlogloss:1.16478	validation_1-mlogloss:1.17612
# [3]	validation_0-mlogloss:1.11229	validation_1-mlogloss:1.12748
# [4]	validation_0-mlogloss:1.06177	validation_1-mlogloss:1.07961
# [5]	validation_0-mlogloss:1.01696	validation_1-mlogloss:1.03815
# [6]	validation_0-mlogloss:0.976704	validation_1-mlogloss:0.998326
# [7]	validation_0-mlogloss:0.943761	validation_1-mlogloss:0.968433
# [8]	validation_0-mlogloss:0.909007	validation_1-mlogloss:0.934203
# [9]	validation_0-mlogloss:0.880412	validation_1-mlogloss:0.907396
# [10]	validation_0-mlogloss:0.852196	validation_1-mlogloss:0.883544
# [11]	validation_0-mlogloss:0.827666	validation_1-mlogloss:0.860295
# [12]	validation_0-mlogloss:0.806408	validation_1-mlogloss:0.84061
# [13]	validation_0-mlogloss:0.78849	validation_1-mlogloss:0.82507
# [14]	validation_0-mlogloss:0.770136	validation_1-mlogloss:0.807466
# [15]	validation_0-mlogloss:0.753526	validation_1-mlogloss:0.793602
# [16]	validation_0-mlogloss:0.737974	validation_1-mlogloss:0.779299
# [17]	validation_0-mlogloss:0.722747	validation_1-mlogloss:0.76674
# [18]	validation_0-mlogloss:0.709198	validation_1-mlogloss:0.75416
# [19]	validation_0-mlogloss:0.695989	validation_1-mlogloss:0.742367
# [20]	validation_0-mlogloss:0.683264	validation_1-mlogloss:0.731526
# [21]	validation_0-mlogloss:0.670716	validation_1-mlogloss:0.719748
# [22]	validation_0-mlogloss:0.66031	validation_1-mlogloss:0.711428
# [23]	validation_0-mlogloss:0.65037	validation_1-mlogloss:0.704751
# [24]	validation_0-mlogloss:0.641245	validation_1-mlogloss:0.696874
# [25]	validation_0-mlogloss:0.632259	validation_1-mlogloss:0.687908
# [26]	validation_0-mlogloss:0.624063	validation_1-mlogloss:0.680052
# [27]	validation_0-mlogloss:0.615477	validation_1-mlogloss:0.673333
# [28]	validation_0-mlogloss:0.607329	validation_1-mlogloss:0.668111
# [29]	validation_0-mlogloss:0.599327	validation_1-mlogloss:0.662867
# [30]	validation_0-mlogloss:0.592758	validation_1-mlogloss:0.657989
# [31]	validation_0-mlogloss:0.585399	validation_1-mlogloss:0.650963
# [32]	validation_0-mlogloss:0.57937	validation_1-mlogloss:0.646407
# [33]	validation_0-mlogloss:0.573084	validation_1-mlogloss:0.643291
# [34]	validation_0-mlogloss:0.567249	validation_1-mlogloss:0.640541
# [35]	validation_0-mlogloss:0.56075	validation_1-mlogloss:0.638232
# [36]	validation_0-mlogloss:0.55528	validation_1-mlogloss:0.634193
# [37]	validation_0-mlogloss:0.550759	validation_1-mlogloss:0.632082
# [38]	validation_0-mlogloss:0.545151	validation_1-mlogloss:0.628525
# [39]	validation_0-mlogloss:0.539444	validation_1-mlogloss:0.624084
# [40]	validation_0-mlogloss:0.535069	validation_1-mlogloss:0.62185
# [41]	validation_0-mlogloss:0.529814	validation_1-mlogloss:0.618833
# [42]	validation_0-mlogloss:0.526128	validation_1-mlogloss:0.616116
# [43]	validation_0-mlogloss:0.521747	validation_1-mlogloss:0.613738
# [44]	validation_0-mlogloss:0.517708	validation_1-mlogloss:0.611288
# [45]	validation_0-mlogloss:0.513232	validation_1-mlogloss:0.607474
# [46]	validation_0-mlogloss:0.510152	validation_1-mlogloss:0.606353
# [47]	validation_0-mlogloss:0.506308	validation_1-mlogloss:0.603618
# [48]	validation_0-mlogloss:0.503138	validation_1-mlogloss:0.600918
# [49]	validation_0-mlogloss:0.499837	validation_1-mlogloss:0.598991
# [50]	validation_0-mlogloss:0.496056	validation_1-mlogloss:0.595794
# [51]	validation_0-mlogloss:0.492786	validation_1-mlogloss:0.592877
# [52]	validation_0-mlogloss:0.490013	validation_1-mlogloss:0.592655
# [53]	validation_0-mlogloss:0.486598	validation_1-mlogloss:0.590322
# [54]	validation_0-mlogloss:0.483171	validation_1-mlogloss:0.588851
# [55]	validation_0-mlogloss:0.479947	validation_1-mlogloss:0.58798
# [56]	validation_0-mlogloss:0.477385	validation_1-mlogloss:0.585385
# [57]	validation_0-mlogloss:0.474446	validation_1-mlogloss:0.584103
# [58]	validation_0-mlogloss:0.471719	validation_1-mlogloss:0.582537
# [59]	validation_0-mlogloss:0.469249	validation_1-mlogloss:0.581022
# [60]	validation_0-mlogloss:0.46659	validation_1-mlogloss:0.579397
# [61]	validation_0-mlogloss:0.463922	validation_1-mlogloss:0.578828
# [62]	validation_0-mlogloss:0.461099	validation_1-mlogloss:0.578981
# [63]	validation_0-mlogloss:0.458838	validation_1-mlogloss:0.57648
# [64]	validation_0-mlogloss:0.456379	validation_1-mlogloss:0.575612
# [65]	validation_0-mlogloss:0.453894	validation_1-mlogloss:0.573754
# [66]	validation_0-mlogloss:0.451362	validation_1-mlogloss:0.574377
# [67]	validation_0-mlogloss:0.448803	validation_1-mlogloss:0.573327
# [68]	validation_0-mlogloss:0.446169	validation_1-mlogloss:0.571706
# [69]	validation_0-mlogloss:0.443818	validation_1-mlogloss:0.56898
# [70]	validation_0-mlogloss:0.441171	validation_1-mlogloss:0.568067
# [71]	validation_0-mlogloss:0.439517	validation_1-mlogloss:0.567488
# [72]	validation_0-mlogloss:0.437291	validation_1-mlogloss:0.567188
# [73]	validation_0-mlogloss:0.435619	validation_1-mlogloss:0.567289
# [74]	validation_0-mlogloss:0.433904	validation_1-mlogloss:0.565865
# [75]	validation_0-mlogloss:0.431825	validation_1-mlogloss:0.563161
# [76]	validation_0-mlogloss:0.429969	validation_1-mlogloss:0.564231
# [77]	validation_0-mlogloss:0.428348	validation_1-mlogloss:0.563861
# [78]	validation_0-mlogloss:0.426586	validation_1-mlogloss:0.563451
# [79]	validation_0-mlogloss:0.424795	validation_1-mlogloss:0.56392
# [80]	validation_0-mlogloss:0.422638	validation_1-mlogloss:0.563367
# [81]	validation_0-mlogloss:0.420489	validation_1-mlogloss:0.562514
# [82]	validation_0-mlogloss:0.419058	validation_1-mlogloss:0.561548
# [83]	validation_0-mlogloss:0.416861	validation_1-mlogloss:0.560349
# [84]	validation_0-mlogloss:0.415195	validation_1-mlogloss:0.559579
# [85]	validation_0-mlogloss:0.413254	validation_1-mlogloss:0.559727
# [86]	validation_0-mlogloss:0.411946	validation_1-mlogloss:0.559784
# [87]	validation_0-mlogloss:0.409884	validation_1-mlogloss:0.558942
# [88]	validation_0-mlogloss:0.408416	validation_1-mlogloss:0.559889
# [89]	validation_0-mlogloss:0.406788	validation_1-mlogloss:0.558516
# [90]	validation_0-mlogloss:0.404806	validation_1-mlogloss:0.5578
# [91]	validation_0-mlogloss:0.403127	validation_1-mlogloss:0.559162
# [92]	validation_0-mlogloss:0.401453	validation_1-mlogloss:0.557653
# [93]	validation_0-mlogloss:0.400061	validation_1-mlogloss:0.556844
# [94]	validation_0-mlogloss:0.398586	validation_1-mlogloss:0.55734
# [95]	validation_0-mlogloss:0.396857	validation_1-mlogloss:0.55642
# [96]	validation_0-mlogloss:0.395165	validation_1-mlogloss:0.554899
# [97]	validation_0-mlogloss:0.393899	validation_1-mlogloss:0.554601
# [98]	validation_0-mlogloss:0.392369	validation_1-mlogloss:0.55346
# [99]	validation_0-mlogloss:0.390973	validation_1-mlogloss:0.552941
# 0.7514792899408284
# 标签顺序:
# [1, 2, 3, 4]
# 测试集混淆矩阵:
# [[27  3  0  0]
#  [ 4 61  8  0]
#  [ 0 18 33  4]
#  [ 0  0  5  6]]
# 训练集混淆矩阵:
# [[301  39   2   0]
#  [ 17 604  46   0]
#  [  0  81 365   2]
#  [  0   1   7  48]]
#              precision    recall  f1-score   support
#
#     class 1       0.87      0.90      0.89        30
#     class 2       0.74      0.84      0.79        73
#     class 3       0.72      0.60      0.65        55
#     class 4       0.60      0.55      0.57        11
#
# avg / total       0.75      0.75      0.75       169
#
# 修正MSE:
# 0.8757396449704142

# %%
model.save_model('q3_xgb0.7514(4分类).model')

# %% [markdown]
# 3分类

# %%
df = pd.read_csv('data/27378.csv',index_col=0)

# 0,1,2合并
# 3,4合并
df['复核结果'].replace(0,1,inplace=True)
df['复核结果'].replace(2,1,inplace=True)
df['复核结果'].replace(3,2,inplace=True)
df['复核结果'].replace(4,2,inplace=True)
df['复核结果'].replace(5,3,inplace=True)

with open('ChineseStopWords/ChineseStopWords.txt', encoding='utf-8') as f:
    stop_words = set([l.strip() for l in f])
    
def segmentWord(cont):
    c = []
    b = []
    for i in cont:
        n = 0
        text = ""
        word_list = list(jieba.cut(i, cut_all=False))
        for word in word_list:
            if word not in stop_words and word != '\r\n':
                text += word
                text += ' '
            else:
                n += 1
        c.append(text)
        b.append(n)
    return c,b

df['回答内容'],df['去停频数'] = segmentWord(df['回答内容'])
df['回答长度'] = df['回答内容'].map(lambda x: len(x))
con_data = df['回答内容'].values

token = Tokenizer(num_words=3300)
token.fit_on_texts(con_data)
data_x_mat = token.texts_to_matrix(con_data)
x_data2 = df[['回答长度','去停频数']].values
x_data = np.hstack([data_x_mat,x_data2])
y_data = df['复核结果'].values

x_train, x_test, y_train, y_test = train_test_split(x_data,y_data,test_size=0.1, random_state=2019)
print('训练集分布:')
for i in range(1,4):
    print('{}:{}'.format(i,len(y_train[y_train==i])))

print('测试集分布:')
for i in range(1,4):
    print('{}:{}'.format(i,len(y_test[y_test==i])))
# Out:
# 训练集分布:
# 1:342
# 2:1115
# 3:56
# 测试集分布:
# 1:30
# 2:128
# 3:11

# %%
model = XGBClassifier(
    learning_rate =0.1,
    n_estimators=100,
    max_depth=3,
    min_child_weight=1,
    gamma=0.3,
    subsample=0.8,
    colsample_bytree=0.8,
    reg_alpha=0,
    reg_lambda=1,
    objective= 'multi:softmax',
    nthread=-1,
    scale_pos_weight=1,
    seed=27
)
eval_list = [(x_train,y_train),(x_test,y_test)]
model.fit(x_train,y_train,verbose=True,eval_set=eval_list,eval_metric='mlogloss', early_stopping_rounds=10)
y_pred = model.predict(x_test)
print(accuracy_score(y_test, y_pred))


labels = list(set(y_test))
print('标签顺序:')
print(labels)
print('测试集混淆矩阵:')
print(confusion_matrix(y_test, y_pred, labels = labels))

y_pred_train = model.predict(x_train)
labels = list(set(y_train))
print('训练集混淆矩阵:')
print(confusion_matrix(y_train, y_pred_train, labels = labels))

target_names = ['class 1', 'class 2', 'class 3']
print(classification_report(y_test, y_pred, target_names=target_names))

print ("修正MSE:")
c = [abs(y_test[i] - y_pred[i]) for i in range(len(y_test))]
mse = 1 - sum(c)/(2*len(y_test))
print (mse)
# Out:
# [0]	validation_0-mlogloss:0.992456	validation_1-mlogloss:0.999144
# Multiple eval metrics have been passed: 'validation_1-mlogloss' will be used for early stopping.
#
# Will train until validation_1-mlogloss hasn't improved in 10 rounds.
# [1]	validation_0-mlogloss:0.906113	validation_1-mlogloss:0.917103
# [2]	validation_0-mlogloss:0.830966	validation_1-mlogloss:0.846472
# [3]	validation_0-mlogloss:0.767385	validation_1-mlogloss:0.785828
# [4]	validation_0-mlogloss:0.714253	validation_1-mlogloss:0.737331
# [5]	validation_0-mlogloss:0.666988	validation_1-mlogloss:0.692803
# [6]	validation_0-mlogloss:0.622233	validation_1-mlogloss:0.650466
# [7]	validation_0-mlogloss:0.587456	validation_1-mlogloss:0.615867
# [8]	validation_0-mlogloss:0.552183	validation_1-mlogloss:0.58367
# [9]	validation_0-mlogloss:0.522899	validation_1-mlogloss:0.559069
# [10]	validation_0-mlogloss:0.495158	validation_1-mlogloss:0.532911
# [11]	validation_0-mlogloss:0.472083	validation_1-mlogloss:0.51148
# [12]	validation_0-mlogloss:0.451159	validation_1-mlogloss:0.492391
# [13]	validation_0-mlogloss:0.430158	validation_1-mlogloss:0.474537
# [14]	validation_0-mlogloss:0.411181	validation_1-mlogloss:0.458884
# [15]	validation_0-mlogloss:0.395368	validation_1-mlogloss:0.445122
# [16]	validation_0-mlogloss:0.380816	validation_1-mlogloss:0.432144
# [17]	validation_0-mlogloss:0.367763	validation_1-mlogloss:0.421103
# [18]	validation_0-mlogloss:0.355054	validation_1-mlogloss:0.410094
# [19]	validation_0-mlogloss:0.342982	validation_1-mlogloss:0.400356
# [20]	validation_0-mlogloss:0.333521	validation_1-mlogloss:0.390567
# [21]	validation_0-mlogloss:0.323023	validation_1-mlogloss:0.382088
# [22]	validation_0-mlogloss:0.313735	validation_1-mlogloss:0.375708
# [23]	validation_0-mlogloss:0.305187	validation_1-mlogloss:0.367287
# [24]	validation_0-mlogloss:0.297192	validation_1-mlogloss:0.3595
# [25]	validation_0-mlogloss:0.289536	validation_1-mlogloss:0.35364
# [26]	validation_0-mlogloss:0.28345	validation_1-mlogloss:0.349899
# [27]	validation_0-mlogloss:0.277735	validation_1-mlogloss:0.343847
# [28]	validation_0-mlogloss:0.271802	validation_1-mlogloss:0.338416
# [29]	validation_0-mlogloss:0.266281	validation_1-mlogloss:0.334656
# [30]	validation_0-mlogloss:0.261703	validation_1-mlogloss:0.331188
# [31]	validation_0-mlogloss:0.257236	validation_1-mlogloss:0.325669
# [32]	validation_0-mlogloss:0.252641	validation_1-mlogloss:0.321262
# [33]	validation_0-mlogloss:0.247827	validation_1-mlogloss:0.317721
# [34]	validation_0-mlogloss:0.243672	validation_1-mlogloss:0.315324
# [35]	validation_0-mlogloss:0.239244	validation_1-mlogloss:0.312406
# [36]	validation_0-mlogloss:0.234912	validation_1-mlogloss:0.309247
# [37]	validation_0-mlogloss:0.231193	validation_1-mlogloss:0.306305
# [38]	validation_0-mlogloss:0.227569	validation_1-mlogloss:0.303299
# [39]	validation_0-mlogloss:0.224299	validation_1-mlogloss:0.301553
# [40]	validation_0-mlogloss:0.221407	validation_1-mlogloss:0.30009
# [41]	validation_0-mlogloss:0.218777	validation_1-mlogloss:0.297477
# [42]	validation_0-mlogloss:0.215655	validation_1-mlogloss:0.295536
# [43]	validation_0-mlogloss:0.212495	validation_1-mlogloss:0.292999
# [44]	validation_0-mlogloss:0.210131	validation_1-mlogloss:0.29223
# [45]	validation_0-mlogloss:0.208155	validation_1-mlogloss:0.290413
# [46]	validation_0-mlogloss:0.205483	validation_1-mlogloss:0.288397
# [47]	validation_0-mlogloss:0.203449	validation_1-mlogloss:0.287896
# [48]	validation_0-mlogloss:0.200961	validation_1-mlogloss:0.287939
# [49]	validation_0-mlogloss:0.198865	validation_1-mlogloss:0.287293
# [50]	validation_0-mlogloss:0.196604	validation_1-mlogloss:0.286941
# [51]	validation_0-mlogloss:0.194246	validation_1-mlogloss:0.284824
# [52]	validation_0-mlogloss:0.192451	validation_1-mlogloss:0.282812
# [53]	validation_0-mlogloss:0.190532	validation_1-mlogloss:0.280688
# [54]	validation_0-mlogloss:0.188715	validation_1-mlogloss:0.280043
# [55]	validation_0-mlogloss:0.186906	validation_1-mlogloss:0.277867
# [56]	validation_0-mlogloss:0.185198	validation_1-mlogloss:0.276817
# [57]	validation_0-mlogloss:0.183547	validation_1-mlogloss:0.275572
# [58]	validation_0-mlogloss:0.181849	validation_1-mlogloss:0.275829
# [59]	validation_0-mlogloss:0.180296	validation_1-mlogloss:0.274783
# [60]	validation_0-mlogloss:0.178659	validation_1-mlogloss:0.275001
# [61]	validation_0-mlogloss:0.177204	validation_1-mlogloss:0.274199
# [62]	validation_0-mlogloss:0.175968	validation_1-mlogloss:0.274552
# [63]	validation_0-mlogloss:0.174656	validation_1-mlogloss:0.274013
# [64]	validation_0-mlogloss:0.173183	validation_1-mlogloss:0.27209
# [65]	validation_0-mlogloss:0.171612	validation_1-mlogloss:0.271737
# [66]	validation_0-mlogloss:0.170036	validation_1-mlogloss:0.270667
# [67]	validation_0-mlogloss:0.168843	validation_1-mlogloss:0.269923
# [68]	validation_0-mlogloss:0.167567	validation_1-mlogloss:0.269328
# [69]	validation_0-mlogloss:0.166254	validation_1-mlogloss:0.26864
# [70]	validation_0-mlogloss:0.165062	validation_1-mlogloss:0.268532
# [71]	validation_0-mlogloss:0.163962	validation_1-mlogloss:0.267412
# [72]	validation_0-mlogloss:0.162947	validation_1-mlogloss:0.266611
# [73]	validation_0-mlogloss:0.16171	validation_1-mlogloss:0.26711
# [74]	validation_0-mlogloss:0.160555	validation_1-mlogloss:0.267015
# [75]	validation_0-mlogloss:0.159464	validation_1-mlogloss:0.266916
# [76]	validation_0-mlogloss:0.15849	validation_1-mlogloss:0.266884
# [77]	validation_0-mlogloss:0.15696	validation_1-mlogloss:0.26643
# [78]	validation_0-mlogloss:0.155875	validation_1-mlogloss:0.26583
# [79]	validation_0-mlogloss:0.154864	validation_1-mlogloss:0.265571
# [80]	validation_0-mlogloss:0.153711	validation_1-mlogloss:0.264898
# [81]	validation_0-mlogloss:0.152804	validation_1-mlogloss:0.264272
# [82]	validation_0-mlogloss:0.151534	validation_1-mlogloss:0.262535
# [83]	validation_0-mlogloss:0.150596	validation_1-mlogloss:0.261811
# [84]	validation_0-mlogloss:0.149608	validation_1-mlogloss:0.262336
# [85]	validation_0-mlogloss:0.148759	validation_1-mlogloss:0.263275
# [86]	validation_0-mlogloss:0.147701	validation_1-mlogloss:0.263645
# [87]	validation_0-mlogloss:0.146777	validation_1-mlogloss:0.263801
# [88]	validation_0-mlogloss:0.146001	validation_1-mlogloss:0.264092
# [89]	validation_0-mlogloss:0.145087	validation_1-mlogloss:0.263496
# [90]	validation_0-mlogloss:0.144049	validation_1-mlogloss:0.262624
# [91]	validation_0-mlogloss:0.143192	validation_1-mlogloss:0.262244
# [92]	validation_0-mlogloss:0.142292	validation_1-mlogloss:0.262688
# [93]	validation_0-mlogloss:0.141566	validation_1-mlogloss:0.262463
# Stopping. Best iteration:
# [83]	validation_0-mlogloss:0.150596	validation_1-mlogloss:0.261811
#
# 0.8994082840236687
# 标签顺序:
# [1, 2, 3]
# 测试集混淆矩阵:
# [[ 27   3   0]
#  [  3 120   5]
#  [  0   6   5]]
# 训练集混淆矩阵:
# [[ 295   47    0]
#  [  15 1099    1]
#  [   0   10   46]]
#              precision    recall  f1-score   support
#
#     class 1       0.90      0.90      0.90        30
#     class 2       0.93      0.94      0.93       128
#     class 3       0.50      0.45      0.48        11
#
# avg / total       0.90      0.90      0.90       169
#
# 修正MSE:
# 0.9497041420118343

# %%
model.save_model('q3_xgb0.899(3分类).model')
